# %%
import pandas as pd

# %%
df = pd.read_csv("Cars93.csv")
df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             56 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
df.describe()
# Out:
#               Id  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count  93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean   47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std    26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min     1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%    24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%    47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%    70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max    93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
df.head()
# Out:
#    Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
df.tail()
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 88           21                 NaN  ...          7    187        115     72
# 89           30                 NaN  ...          5    180        103     67
# 90           25                 NaN  ...          4    159         97     66
# 91           28         Driver only  ...          5    190        104     67
# 92           28  Driver & Passenger  ...          5    184        105     69
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               37
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
hi = df["Rear.seat.room"] = df["Rear.seat.room"].fillna("Rear.seat.room").mode()[0]
hi
# Out:
# 26.5

# %%
df.isnull().sum()
# Out:
# Id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               37
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         0
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
df["Luggage.room"] = df["Luggage.room"].fillna("Luggage.room").mode()[0]

# %%
df.isnull().sum()
# Out:
# Id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               37
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         0
# Luggage.room           0
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
df["AirBags"] = df["AirBags"].fillna("AirBags").mode()[0]
df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                    0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %% [markdown]
# find the averrage price of each manufacturer?

# %%
df.groupby("Manufacturer")["Price"].mean()
# Out:
# Manufacturer
# Acura            24.900000
# Audi             33.400000
# BMW              30.000000
# Buick            21.625000
# Cadillac         37.400000
# Chevrolet        18.187500
# Chrylser         18.400000
# Chrysler         22.650000
# Dodge            15.700000
# Eagle            15.750000
# Ford             14.962500
# Geo              10.450000
# Honda            16.466667
# Hyundai          10.475000
# Infiniti         47.900000
# Lexus            31.600000
# Lincoln          35.200000
# Mazda            17.600000
# Mercedes-Benz    46.900000
# Mercury          14.500000
# Mitsubishi       18.200000
# Nissan           17.025000
# Oldsmobile       17.500000
# Plymouth         14.400000
# Pontiac          16.140000
# Saab             28.700000
# Saturn           11.100000
# Subaru           12.933333
# Suzuki            8.600000
# Toyota           17.275000
# Volkswagen       18.025000
# Volvo            24.700000
# Name: Price, dtype: float64

# %%
df["Price"].sort_values()
# Out:
# 30     7.4
# 43     8.0
# 52     8.3
# 38     8.4
# 79     8.4
#       ...
# 3     37.7
# 18    38.0
# 10    40.1
# 47    47.9
# 58    61.9
# Name: Price, Length: 93, dtype: float64

# %%
df.sort_values('Price').head(5)
# Out:
#     Id Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 30  31         Ford  Festiva  Small        6.9    7.4        7.9        31
# 43  44      Hyundai    Excel  Small        6.8    8.0        9.2        29
# 52  53        Mazda      323  Small        7.4    8.3        9.1        29
# 38  39          Geo    Metro  Small        6.7    8.4       10.0        46
# 79  80       Subaru    Justy  Small        7.3    8.4        9.5        33
#
#     MPG.highway      AirBags  ... Passengers Length  Wheelbase  Width  \
# 30           33  Driver only  ...          4    141         90     63
# 43           33  Driver only  ...          5    168         94     63
# 52           37  Driver only  ...          4    164         97     66
# 38           50  Driver only  ...          4    151         93     63
# 79           37  Driver only  ...          4    146         90     60
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# ...

# %% [markdown]
# find the Manufacturer of 5 seater cars?

# %%
Seater = df[df["Passengers"]==5]
Seater
# Out:
#     Id   Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura        Integra    Small       12.9   15.9       18.8
# 1    2          Acura         Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi             90  Compact       25.9   29.1       32.3
# 8    9          Buick        Riviera  Midsize       26.3   26.3       26.3
# 10  11       Cadillac        Seville  Midsize       37.5   40.1       42.7
# 11  12      Chevrolet       Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet        Corsica  Compact       11.4   11.4       11.4
# 22  23          Dodge           Colt    Small        7.9    9.2       10.6
# 23  24          Dodge         Shadow    Small        8.4   11.3       14.2
# 28  29          Eagle         Summit    Small        7.9   12.2       16.5
# 31  32           Ford         Escort    Small        8.4   10.1       11.9
# ...

# %%
Seater["Manufacturer"]
# Out:
# 0             Acura
# 1             Acura
# 2              Audi
# 8             Buick
# 10         Cadillac
# 11        Chevrolet
# 12        Chevrolet
# 22            Dodge
# 23            Dodge
# 28            Eagle
# 31             Ford
# 32             Ford
# 36             Ford
# 43          Hyundai
# 44          Hyundai
# 46          Hyundai
# 47         Infiniti
# 48            Lexus
# 53            Mazda
# 54            Mazda
# 57    Mercedes-Benz
# 58    Mercedes-Benz
# 60          Mercury
# 61       Mitsubishi
# 62       Mitsubishi
# 63           Nissan
# 64           Nissan
# 66           Nissan
# 67       Oldsmobile
# 68       Oldsmobile
# 73          Pontiac
# 75          Pontiac
# 77             Saab
# 78           Saturn
# 80           Subaru
# 81           Subaru
# 83           Toyota
# 85           Toyota
# 89       Volkswagen
# 91            Volvo
# 92            Volvo
# Name: Manufacturer, dtype: object

# %%
Seater[["Manufacturer","Model","Price"]]
# Out:
#      Manufacturer          Model  Price
# 0           Acura        Integra   15.9
# 1           Acura         Legend   33.9
# 2            Audi             90   29.1
# 8           Buick        Riviera   26.3
# 10       Cadillac        Seville   40.1
# 11      Chevrolet       Cavalier   13.4
# 12      Chevrolet        Corsica   11.4
# 22          Dodge           Colt    9.2
# 23          Dodge         Shadow   11.3
# 28          Eagle         Summit   12.2
# 31           Ford         Escort   10.1
# 32           Ford          Tempo   11.3
# 36           Ford         Taurus   20.2
# 43        Hyundai          Excel    8.0
# 44        Hyundai        Elantra   10.0
# 46        Hyundai         Sonata   13.9
# 47       Infiniti            Q45   47.9
# 48          Lexus          ES300   28.0
# 53          Mazda        Protege   11.6
# 54          Mazda            626   16.5
# 57  Mercedes-Benz           190E   31.9
# 58  Mercedes-Benz           300E   61.9
# ...

# %%
Seater[["Type","Max.Price","Min.Price"]]
# Out:
#        Type  Max.Price  Min.Price
# 0     Small       18.8       12.9
# 1   Midsize       38.7       29.2
# 2   Compact       32.3       25.9
# 8   Midsize       26.3       26.3
# 10  Midsize       42.7       37.5
# 11  Compact       18.3        8.5
# 12  Compact       11.4       11.4
# 22    Small       10.6        7.9
# 23    Small       14.2        8.4
# 28    Small       16.5        7.9
# 31    Small       11.9        8.4
# 32  Compact       12.2       10.4
# 36  Midsize       24.8       15.6
# 43    Small        9.2        6.8
# 44    Small       11.0        9.0
# 46  Midsize       15.3       12.4
# 47  Midsize       50.4       45.4
# 48  Midsize       28.4       27.5
# 53    Small       12.3       10.9
# 54  Compact       18.7       14.3
# 57  Compact       34.9       29.0
# 58  Midsize       80.0       43.8
# 60  Midsize       14.9       14.9
# 61    Small       12.9        7.7
# 62  Midsize       29.9       22.4
# 63    Small       14.9        8.7
# ...

# %%
df["difference"] = df["Max.Price"] - df["Min.Price"]

# %%
df[["difference","Max.Price","Min.Price"]]
# Out:
#     difference  Max.Price  Min.Price
# 0          5.9       18.8       12.9
# 1          9.5       38.7       29.2
# 2          6.4       32.3       25.9
# 3         13.8       44.6       30.8
# 4         12.5       36.2       23.7
# ..         ...        ...        ...
# 88         6.1       22.7       16.6
# 89         4.8       22.4       17.6
# 90         0.8       23.7       22.9
# 91         1.7       23.5       21.8
# 92         3.7       28.5       24.8
#
# [93 rows x 3 columns]

# %%
df.head()
# Out:
#    Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway      AirBags  ... Length Wheelbase  Width  Turn.circle  \
# 0           31  Driver only  ...    177       102     68           37
# 1           25  Driver only  ...    195       115     71           38
# 2           26  Driver only  ...    180       102     67           37
# 3           26  Driver only  ...    193       106     70           37
# 4           30  Driver only  ...    186       109     69           39
#
#    Rear.seat.room  Luggage.room Weight   Origin           Make  difference
# ...

# %%
df[df["MPG.highway"]>30]
# Out:
#     Id Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0    1        Acura        Integra    Small       12.9   15.9       18.8
# 5    6        Buick        Century  Midsize       14.2   15.7       17.3
# 11  12    Chevrolet       Cavalier  Compact        8.5   13.4       18.3
# 12  13    Chevrolet        Corsica  Compact       11.4   11.4       11.4
# 22  23        Dodge           Colt    Small        7.9    9.2       10.6
# 28  29        Eagle         Summit    Small        7.9   12.2       16.5
# 30  31         Ford        Festiva    Small        6.9    7.4        7.9
# 38  39          Geo          Metro    Small        6.7    8.4       10.0
# 39  40          Geo          Storm   Sporty       11.5   12.5       13.5
# 40  41        Honda        Prelude   Sporty       17.0   19.8       22.7
# 41  42        Honda          Civic    Small        8.4   12.1       15.8
# 42  43        Honda         Accord  Compact       13.8   17.5       21.2
# ...

# %% [markdown]
# FIND THE MANUFACTURER AND MIN PRICE

# %%
df[["Manufacturer","Min.Price"]].sort_values("Min.Price").head(10)
# Out:
#    Manufacturer  Min.Price
# 38          Geo        6.7
# 43      Hyundai        6.8
# 30         Ford        6.9
# 79       Subaru        7.3
# 82       Suzuki        7.3
# 52        Mazda        7.4
# 61   Mitsubishi        7.7
# 83       Toyota        7.8
# 28        Eagle        7.9
# 22        Dodge        7.9

# %% [markdown]
# find the airbags where drivers only?

# %%
df[df["AirBags"]=="Driver only"]
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
car = df[df["AirBags"]=="Driver only"]
car
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
car.sort_values("Max.Price",ascending=False).head(1)
# Out:
#     Id   Manufacturer Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 58  59  Mercedes-Benz  300E  Midsize       43.8   61.9       80.0        19
#
#     MPG.highway      AirBags  ... Length Wheelbase  Width  Turn.circle  \
# 58           25  Driver only  ...    187       110     69           37
#
#     Rear.seat.room  Luggage.room Weight   Origin                Make  \
# 58            26.5          14.0   3525  non-USA  Mercedes-Benz 300E
#
#     difference
# 58        36.2
#
# [1 rows x 29 columns]

# %%
car.sort_values("Min.Price").head(1)
# Out:
#     Id Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo  Metro  Small        6.7    8.4       10.0        46
#
#     MPG.highway      AirBags  ... Length Wheelbase  Width  Turn.circle  \
# 38           50  Driver only  ...    151        93     63           34
#
#     Rear.seat.room  Luggage.room Weight   Origin       Make  difference
# 38            26.5          14.0   1695  non-USA  Geo Metro         3.3
#
# [1 rows x 29 columns]

# %%
df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# find the average weight of the car ?

# %%
df.groupby("Manufacturer")["Weight"].mean()
# Out:
# Manufacturer
# Acura            3132.500000
# Audi             3390.000000
# BMW              3640.000000
# Buick            3487.500000
# Cadillac         3777.500000
# Chevrolet        3342.500000
# Chrylser         3515.000000
# Chrysler         3327.500000
# Dodge            3083.333333
# Eagle            2892.500000
# Ford             2954.375000
# Geo              2085.000000
# Honda            2751.666667
# Hyundai          2533.750000
# Infiniti         4000.000000
# Lexus            3512.500000
# Lincoln          3875.000000
# Mazda            2873.000000
# Mercedes-Benz    3222.500000
# Mercury          3030.000000
# Mitsubishi       3012.500000
# Nissan           3223.750000
# Oldsmobile       3246.250000
# Plymouth         2640.000000
# Pontiac          3022.000000
# Saab             2775.000000
# Saturn           2495.000000
# Subaru           2540.000000
# Suzuki           1965.000000
# Toyota           2955.000000
# Volkswagen       2998.750000
# ...

# %%
tesla = df.groupby("Manufacturer")["Weight"].mean()

# %%
gt = df["Weight"].mean()
gt
# Out:
# np.float64(3072.9032258064517)

# %%
df[df["Weight"] > gt]
# Out:
#     Id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# 13  14      Chevrolet          Camaro   Sporty       13.4   15.1       16.8
# 14  15      Chevrolet          Lumina  Midsize       13.4   15.9       18.4
# ...

# %% [markdown]
# count tha sporty car

# %%
gt = df[df["Type"]=="Sporty"]

# %%
gt.value_counts().sum()
# Out:
# np.int64(14)

# %%
alokcharce = df["Area"] = df["Length"] * df["Width"]

# %%
df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
df.sort_values("Area",ascending=False).head(5)
# Out:
#     Id Manufacturer           Model   Type  Min.Price  Price  Max.Price  \
# 51  52      Lincoln        Town_Car  Large       34.4   36.1       37.8
# 7    8        Buick      Roadmaster  Large       22.6   23.7       24.9
# 37  38         Ford  Crown_Victoria  Large       20.1   20.9       21.7
# 17  18    Chevrolet         Caprice  Large       18.0   18.8       19.6
# 16  17    Chevrolet           Astro    Van       14.7   16.6       18.6
#
#     MPG.city  MPG.highway      AirBags  ... Wheelbase Width  Turn.circle  \
# 51        18           26  Driver only  ...       117    77           45
# 7         16           25  Driver only  ...       116    78           45
# 37        18           26  Driver only  ...       114    78           43
# 17        17           26  Driver only  ...       116    77           42
# 16        15           20  Driver only  ...       111    78           42
#
#     Rear.seat.room  Luggage.room  Weight Origin                 Make  \
# ...

# %%
df[df["MPG.city"]>20]
# Out:
#     Id Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0    1        Acura        Integra    Small       12.9   15.9       18.8
# 4    5          BMW           535i  Midsize       23.7   30.0       36.2
# 5    6        Buick        Century  Midsize       14.2   15.7       17.3
# 11  12    Chevrolet       Cavalier  Compact        8.5   13.4       18.3
# 12  13    Chevrolet        Corsica  Compact       11.4   11.4       11.4
# 14  15    Chevrolet         Lumina  Midsize       13.4   15.9       18.4
# 20  21     Chrysler        LeBaron  Compact       14.5   15.8       17.1
# 22  23        Dodge           Colt    Small        7.9    9.2       10.6
# 23  24        Dodge         Shadow    Small        8.4   11.3       14.2
# 24  25        Dodge         Spirit  Compact       11.9   13.3       14.7
# 26  27        Dodge        Dynasty  Midsize       14.8   15.6       16.4
# 28  29        Eagle         Summit    Small        7.9   12.2       16.5
# ...

# %%
BMW = df["MPG.city"].mean()
BMW
# Out:
# np.float64(22.365591397849464)

# %%
import numpy as np
df["MPG.city"] = np.where((df["MPG.city"] < BMW),df["MPG.city"] + 2, df["MPG.city"])

# %%
df["MPG.city"]
# Out:
# 0     25
# 1     20
# 2     22
# 3     21
# 4     24
#       ..
# 88    19
# 89    23
# 90    20
# 91    23
# 92    22
# Name: MPG.city, Length: 93, dtype: int64

# %%
df[df["Origin"]=="USA"]
# Out:
#     Id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 5    6        Buick         Century  Midsize       14.2   15.7       17.3
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9        Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10     Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11     Cadillac         Seville  Midsize       37.5   40.1       42.7
# 11  12    Chevrolet        Cavalier  Compact        8.5   13.4       18.3
# 12  13    Chevrolet         Corsica  Compact       11.4   11.4       11.4
# 13  14    Chevrolet          Camaro   Sporty       13.4   15.1       16.8
# 14  15    Chevrolet          Lumina  Midsize       13.4   15.9       18.4
# 15  16    Chevrolet      Lumina_APV      Van       14.7   16.3       18.0
# 16  17    Chevrolet           Astro      Van       14.7   16.6       18.6
# ...

# %%
df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        20
# 2    3         Audi       90  Compact       25.9   29.1       32.3        22
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        21
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        24
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        19
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        23
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        20
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        23
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        22
#
# ...

# %% [markdown]
# find any milage for each manufacturer

# %%
mileage_by_manufacturer = df.groupby("Manufacturer")[["MPG.city", "MPG.highway"]].mean()
mileage_by_manufacturer
# Out:
#                MPG.city  MPG.highway
# Manufacturer
# Acura            22.500    28.000000
# Audi             21.500    26.000000
# BMW              24.000    30.000000
# Buick            21.000    27.750000
# Cadillac         18.000    25.000000
# Chevrolet        21.125    27.625000
# Chrylser         22.000    28.000000
# Chrysler         22.500    27.000000
# Dodge            23.000    26.833333
# Eagle            25.500    30.500000
# Ford             23.250    28.125000
# Geo              38.000    43.000000
# Honda            30.000    36.000000
# Hyundai          25.250    30.750000
# Infiniti         19.000    22.000000
# Lexus            20.000    23.500000
# Lincoln          19.500    26.000000
# Mazda            24.400    31.200000
# Mercedes-Benz    21.500    27.000000
# Mercury          22.000    26.000000
# Mitsubishi       24.500    28.500000
# Nissan           23.750    28.000000
# Oldsmobile       22.000    28.250000
# Plymouth         23.000    30.000000
# ...

# %% [markdown]
# find the any weight of cars of type small

# %% [markdown]
# FIRST METHOD

# %%
df[df["Type"]=="Small"]["Weight"].mean()
# Out:
# np.float64(2312.8571428571427)

# %% [markdown]
# SECOND METHOD

# %%
Small = df[df["Type"]=="Small"]

# %%
Small["Weight"].mean()
# Out:
# np.float64(2312.8571428571427)

# %% [markdown]
# find the horsepower and enginesize top 10 cars

# %%
TOP = df[["Manufacturer","EngineSize","Horsepower"]].sort_values("Horsepower").head(10)
TOP
# Out:
#    Manufacturer  EngineSize  Horsepower
# 38          Geo         1.0          55
# 30         Ford         1.3          63
# 82       Suzuki         1.3          70
# 79       Subaru         1.2          73
# 72      Pontiac         1.6          74
# 87   Volkswagen         1.8          81
# 43      Hyundai         1.5          81
# 52        Mazda         1.6          82
# 83       Toyota         1.5          82
# 78       Saturn         1.9          85

# %%
car = df[df["Origin"]=="non-USA"]
car
# Out:
#     Id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura   Integra    Small       12.9   15.9       18.8
# 1    2          Acura    Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 3    4           Audi       100  Midsize       30.8   37.7       44.6
# 4    5            BMW      535i  Midsize       23.7   30.0       36.2
# 38  39            Geo     Metro    Small        6.7    8.4       10.0
# 39  40            Geo     Storm   Sporty       11.5   12.5       13.5
# 40  41          Honda   Prelude   Sporty       17.0   19.8       22.7
# 41  42          Honda     Civic    Small        8.4   12.1       15.8
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 43  44        Hyundai     Excel    Small        6.8    8.0        9.2
# 44  45        Hyundai   Elantra    Small        9.0   10.0       11.0
# ...

# %%
car.sort_values("MPG.city",ascending=False)
car
# Out:
#     Id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura   Integra    Small       12.9   15.9       18.8
# 1    2          Acura    Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 3    4           Audi       100  Midsize       30.8   37.7       44.6
# 4    5            BMW      535i  Midsize       23.7   30.0       36.2
# 38  39            Geo     Metro    Small        6.7    8.4       10.0
# 39  40            Geo     Storm   Sporty       11.5   12.5       13.5
# 40  41          Honda   Prelude   Sporty       17.0   19.8       22.7
# 41  42          Honda     Civic    Small        8.4   12.1       15.8
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 43  44        Hyundai     Excel    Small        6.8    8.0        9.2
# 44  45        Hyundai   Elantra    Small        9.0   10.0       11.0
# ...

# %%
from numpy._core.defchararray import index
df.pivot_table(index ="Manufacturer",
columns="Type",
values="Price",
aggfunc="mean")
# Out:
# Type           Compact  Large  Midsize  Small  Sporty    Van
# Manufacturer
# Acura              NaN    NaN     33.9  15.90     NaN    NaN
# Audi              29.1    NaN     37.7    NaN     NaN    NaN
# BMW                NaN    NaN     30.0    NaN     NaN    NaN
# Buick              NaN  22.25     21.0    NaN     NaN    NaN
# Cadillac           NaN  34.70     40.1    NaN     NaN    NaN
# Chevrolet         12.4  18.80     15.9    NaN   26.55  16.45
# Chrylser           NaN  18.40      NaN    NaN     NaN    NaN
# Chrysler          15.8  29.50      NaN    NaN     NaN    NaN
# Dodge             13.3    NaN     15.6  10.25   25.80  19.00
# Eagle              NaN  19.30      NaN  12.20     NaN    NaN
# Ford              11.3  20.90     20.2   8.75   14.95  19.90
# Geo                NaN    NaN      NaN   8.40   12.50    NaN
# Honda             17.5    NaN      NaN  12.10   19.80    NaN
# Hyundai            NaN    NaN     13.9   9.00   10.00    NaN
# ...
